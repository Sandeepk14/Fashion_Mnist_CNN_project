# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandeepk14/Fashion_Mnist_CNN_project/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# `Aim`: The primary aim of the Fashion MNIST (FNIST) project is to develop and train a machine learning or deep learning model, typically using Convolutional Neural Networks (CNNs), to classify grayscale images of fashion items into 10 distinct categories accurately. These categories include:
# -T-shirt/top
# -Trouser
# -Pullover
# -Dress
# -Coat
# -Sandal
# -Shirt
# -Sneaker
# -Bag
# -Ankle boot

# %%
# import libraries
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt
import numpy as np

# %%
# Load and preprocess the dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# total number of classes
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i].reshape(28, 28), cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i].argmax()])
plt.show()

# %%
x_train = x_train.reshape(-1, 28, 28, 1).astype("float32") / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype("float32") / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Modify the model to include dropout layers
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(x_train, y_train, epochs=100, batch_size=64, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.6445 - loss: 0.9786 - val_accuracy: 0.8395 - val_loss: 0.4432
# Epoch 2/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 50s 67ms/step - accuracy: 0.8163 - loss: 0.5049 - val_accuracy: 0.8725 - val_loss: 0.3621
# Epoch 3/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 83s 68ms/step - accuracy: 0.8448 - loss: 0.4230 - val_accuracy: 0.8763 - val_loss: 0.3317
# Epoch 4/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 46s 62ms/step - accuracy: 0.8618 - loss: 0.3858 - val_accuracy: 0.8869 - val_loss: 0.3041
# Epoch 5/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 84s 65ms/step - accuracy: 0.8694 - loss: 0.3643 - val_accuracy: 0.8857 - val_loss: 0.3012
# Epoch 6/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 79s 61ms/step - accuracy: 0.8766 - loss: 0.3387 - val_accuracy: 0.8957 - val_loss: 0.2763
# Epoch 7/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 81s 61ms/step - accuracy: 0.8810 - loss: 0.3246 - val_accuracy: 0.8986 - val_loss: 0.2690
# Epoch 8/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 84s 63ms/step - accuracy: 0.8855 - loss: 0.3187 - val_accuracy: 0.8967 - val_loss: 0.2723
# Epoch 9/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 84s 66ms/step - accuracy: 0.8907 - loss: 0.2981 - val_accuracy: 0.9038 - val_loss: 0.2556
# Epoch 10/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 80s 64ms/step - accuracy: 0.8903 - loss: 0.2955 - val_accuracy: 0.9055 - val_loss: 0.2524
# Epoch 11/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 82s 64ms/step - accuracy: 0.8958 - loss: 0.2857 - val_accuracy: 0.9050 - val_loss: 0.2501
# Epoch 12/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 80s 61ms/step - accuracy: 0.8974 - loss: 0.2786 - val_accuracy: 0.9052 - val_loss: 0.2546
# Epoch 13/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 48s 64ms/step - accuracy: 0.8980 - loss: 0.2738 - val_accuracy: 0.9067 - val_loss: 0.2477
# Epoch 14/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 82s 64ms/step - accuracy: 0.8995 - loss: 0.2681 - val_accuracy: 0.9107 - val_loss: 0.2417
# Epoch 15/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 80s 61ms/step - accuracy: 0.9012 - loss: 0.2661 - val_accuracy: 0.9097 - val_loss: 0.2392
# Epoch 16/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 84s 64ms/step - accuracy: 0.9037 - loss: 0.2587 - val_accuracy: 0.9107 - val_loss: 0.2389
# Epoch 17/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 46s 61ms/step - accuracy: 0.9038 - loss: 0.2622 - val_accuracy: 0.9133 - val_loss: 0.2342
# Epoch 18/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 80s 59ms/step - accuracy: 0.9049 - loss: 0.2535 - val_accuracy: 0.9037 - val_loss: 0.2518
# Epoch 19/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 82s 60ms/step - accuracy: 0.9070 - loss: 0.2495 - val_accuracy: 0.9122 - val_loss: 0.2373
# Epoch 20/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 82s 60ms/step - accuracy: 0.9120 - loss: 0.2403 - val_accuracy: 0.9118 - val_loss: 0.2317
# Epoch 21/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 46s 61ms/step - accuracy: 0.9105 - loss: 0.2442 - val_accuracy: 0.9138 - val_loss: 0.2326
# Epoch 22/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 82s 61ms/step - accuracy: 0.9122 - loss: 0.2419 - val_accuracy: 0.9142 - val_loss: 0.2261
# Epoch 23/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 84s 63ms/step - accuracy: 0.9108 - loss: 0.2353 - val_accuracy: 0.9162 - val_loss: 0.2300
# Epoch 24/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 80s 61ms/step - accuracy: 0.9129 - loss: 0.2336 - val_accuracy: 0.9108 - val_loss: 0.2342
# Epoch 25/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 45s 59ms/step - accuracy: 0.9124 - loss: 0.2316 - val_accuracy: 0.9148 - val_loss: 0.2315

# %%
#plot the model structure
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# 313/313 - 3s - 8ms/step - accuracy: 0.9104 - loss: 0.2461
# Test Accuracy: 0.91

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
